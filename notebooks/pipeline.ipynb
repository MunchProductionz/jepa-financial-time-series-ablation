# %% [markdown]
# # Pipeline
#
# This notebook imports the same package functions used by CLI runs. It is intentionally thin so research logic stays in `src/ablation_study_jepa/`.

# %%
from pathlib import Path
from ablation_study_jepa.config.loader import load_config
from ablation_study_jepa.api.experiment import ExperimentRunner

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()

# %%
experiment_config = load_config(root / 'configs/exp/lstm.yaml')
experiment_config.data.data_dir = root / 'data/prices'
experiment_config.data.macro_data_path = root / 'data/macro/fred_md/fred_md_1960_2025.csv'
experiment_config.evaluation.predictions_dir = root / 'predictions'

result = ExperimentRunner(experiment_config).run()
result
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# /Users/henrrb/Desktop/NTNU/Research/jepa-financial-time-series-ablation/.venv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ┏━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name            ┃ Type           ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model           │ TFT            │  1.5 M │ train │     0 │
# │ 1 │ criterion       │ MSELoss        │      0 │ train │     0 │
# │ 2 │ loss_aggregator │ LossAggregator │      0 │ train │     0 │
# └───┴─────────────────┴────────────────┴────────┴───────┴───────┘
# Trainable params: 1.5 M
# Non-trainable params: 0
# Total params: 1.5 M
# Total estimated model params size (MB): 5
# Modules in train mode: 113
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# /Users/henrrb/Desktop/NTNU/Research/jepa-financial-time-series-ablation/.venv/lib/python3.11/site-packages/lightnin
# g/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec,
# TreeSpec) and treespec.is_leaf()` instead.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   test/prediction_loss    │   0.0003517831792123616   │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#   "test": {
#     "correlation": 0.034687739706893136,
#     "directional_accuracy": 0.49390243902439024,
#     "mae": 0.014556590600299393,
#     "mse": 0.00035178324120266693,
#     "spearman_rank_ic": 0.033643160082940445,
#     "top_bottom_quantile_spread": 0.0009385209458781425
#   },
#   "val": {
#     "correlation": -0.021127371434404636,
#     "directional_accuracy": 0.48080279232111695,
#     "mae": 0.015604224850609413,
#     "mse": 0.00039370601151383916,
#     "spearman_rank_ic": 0.015000054332972267,
#     "top_bottom_quantile_spread": -0.00022126853840832936
#   }
# }
# ExperimentResult(run_name='tft_no_jepa_1d', val_metrics={'mse': 0.00039370601151383916, 'mae': 0.015604224850609413, 'correlation': -0.021127371434404636, 'directional_accuracy': 0.48080279232111695, 'spearman_rank_ic': 0.015000054332972267, 'top_bottom_quantile_spread': -0.00022126853840832936}, test_metrics={'mse': 0.00035178324120266693, 'mae': 0.014556590600299393, 'correlation': 0.034687739706893136, 'directional_accuracy': 0.49390243902439024, 'spearman_rank_ic': 0.033643160082940445, 'top_bottom_quantile_spread': 0.0009385209458781425}, prediction_paths={'val': PosixPath('/Users/henrrb/Desktop/NTNU/Research/jepa-financial-time-series-ablation/predictions/tft_no_jepa_1d_baseline_no_jepa_tft_20260509T223454Z_f3e7f5d123/val.csv'), 'test': PosixPath('/Users/henrrb/Desktop/NTNU/Research/jepa-financial-time-series-ablation/predictions/tft_no_jepa_1d_baseline_no_jepa_tft_20260509T223454Z_f3e7f5d123/test.csv')}, metrics_path=PosixPath('/Users/henrrb/Desktop/NTNU/Research/jepa-financial-time-series-ablation/predictions/tft_no_jepa_1d_baseline_no_jepa_tft_20260509T223454Z_f3e7f5d123/metrics.json'))
